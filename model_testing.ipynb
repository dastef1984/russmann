# %% [markdown]
# In this notebook, I've tested three recommendation models from the RecBole framework: Bayesian Personalized Ranking (BPR), Factorization Machines (FM), and Attentional Factorization Machines (AFM), focusing on their ability to handle both implicit and explicit feedback.
#
# **Key Findings:**
# 1. **BPR**: It looks like BPR doesn't really use the rating values—it just cares whether users have interacted with items or not. This means BPR might not be the best choice if we need to distinguish between different levels of user preferences, which is important for explicit feedback.
# 2. **FM**: This model can handle both types of feedback. However, it struggles with ranking tasks since it's primarily built for prediction. This means using FM with top-k evaluation metrics (like precision or recall) isn't straightforward and might require additional tweaks or different settings.
# 3. **AFM**: AFM works well with both implicit and explicit feedback thanks to its attention mechanism that highlights important interactions. But just like FM, we didn't test it with top-k metrics for explicit feedback, so we can't say for sure how well it would perform in ranking scenarios. The results also were not identical, but very similar to FM, so both methods seem to work in a similar way.

# %% [markdown]
# 1. **BPR**:
# The results from the experiments testing the BPR model with different rating configurations show that BPR performs similarly whether ratings are thresholded or all set to one. This similarity in performance suggests that for BPR, the presence of an interaction is more important than the rating's magnitude. BPR optimizes based on pairwise rankings of observed versus unobserved interactions, focusing on the presence rather than the strength of preferences. This makes BPR suitable for scenarios where explicit ratings are sparse or not available, as it effectively utilizes binary interaction data. If different levels of user satisfaction significantly impact recommendations, exploring models that can distinguish these levels or incorporating additional data might be necessary.

# %%
import pandas as pd
from recbole.quick_start import run_recbole

# Load and convert data to implicit feedback
data = pd.read_csv('u.data', sep='\t', names=['user_id', 'item_id', 'rating', 'timestamp'])
threshold = 3.5
data['rating'] = (data['rating'] > threshold).astype(int)

# Save binary data
data.to_csv('dataset/ml100k_implicit_bpr/ml100k_implicit_bpr.inter', index=False, sep='\t', header=['user_id:token', 'item_id:token', 'rating:float', 'timestamp:float'])
# Configuration for running BPR with Implicit Feedback
config_dict_implicit = {
    'model': 'BPR',
    'dataset': 'ml100k_implicit_bpr',
    'learning_rate': 0.01,
    'epochs': 100,
    'embedding_size': 64,
    'eval_setting': 'RO_RS',
    'metrics': ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision'],
    'valid_metric': 'MRR@10',
    'topk': 10,
    'gpu_id': 0,
    'early_stop': 5,
}

# Run the model for implicit feedback
run_recbole(model='BPR', dataset='ml100k_implicit_bpr', config_dict=config_dict_implicit)
# Out:
# /home/stef/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/stef/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 23 May 15:41    INFO  ['/home/stef/.local/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/home/stef/.local/share/jupyter/runtime/kernel-510548df-5f9c-4af3-8da9-9e6950dbae6c.json']
# 23 May 15:41    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/ml100k_implicit_bpr
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.01
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# eval_setting = RO_RS
# early_stop = 5
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# /home/stef/.local/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# 23 May 15:41    INFO  ml100k_implicit_bpr
# The number of users: 944
# Average actions of users: 106.04453870625663
# The number of items: 1683
# Average actions of items: 59.45303210463734
# The number of inters: 100000
# The sparsity of the dataset: 93.70575143257098%
# Remain Fields: ['user_id', 'item_id']
# 23 May 15:41    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 23 May 15:41    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 23 May 15:41    INFO  BPR(
#   (user_embedding): Embedding(944, 64)
#   (item_embedding): Embedding(1683, 64)
#   (loss): BPRLoss()
# )
# Trainable parameters: 168128
# 23 May 15:41    INFO  FLOPs: 128.0
# Train     0:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  28%|█████████████▍                                   | 11/40 [00:00<00:00, 109.41it/s]:  80%|███████████████████████████████████████▏         | 32/40 [00:00<00:00, 167.85it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 164.57it/s]
# 23 May 15:41    INFO  epoch 0 training [time: 0.25s, train loss: 25.2600]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  56%|█████████████████████████▋                    | 264/472 [00:00<00:00, 2630.83it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2547.76it/s]
# 23 May 15:41    INFO  epoch 0 evaluating [time: 0.20s, valid_score: 0.263900]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1154    mrr@10 : 0.2639    ndcg@10 : 0.1371    hit@10 : 0.5525    precision@10 : 0.1011
# 23 May 15:41    INFO  Saving current: saved/BPR-May-23-2024_15-41-36.pth
# Train     1:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  52%|█████████████████████████▋                       | 21/40 [00:00<00:00, 203.78it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 228.64it/s]
# 23 May 15:41    INFO  epoch 1 training [time: 0.18s, train loss: 13.0037]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  66%|██████████████████████████████▎               | 311/472 [00:00<00:00, 3109.74it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2835.37it/s]
# 23 May 15:41    INFO  epoch 1 evaluating [time: 0.18s, valid_score: 0.308100]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1488    mrr@10 : 0.3081    ndcg@10 : 0.1682    hit@10 : 0.6278    precision@10 : 0.1144
# 23 May 15:41    INFO  Saving current: saved/BPR-May-23-2024_15-41-36.pth
# Train     2:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  57%|████████████████████████████▏                    | 23/40 [00:00<00:00, 221.44it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 200.78it/s]
# 23 May 15:41    INFO  epoch 2 training [time: 0.20s, train loss: 9.8429]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  68%|███████████████████████████████▎              | 321/472 [00:00<00:00, 3199.35it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 3032.11it/s]
# 23 May 15:41    INFO  epoch 2 evaluating [time: 0.17s, valid_score: 0.319100]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1779    mrr@10 : 0.3191    ndcg@10 : 0.1892    hit@10 : 0.6797    precision@10 : 0.1334
# 23 May 15:41    INFO  Saving current: saved/BPR-May-23-2024_15-41-36.pth
# Train     3:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  55%|██████████████████████████▉                      | 22/40 [00:00<00:00, 213.34it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 216.52it/s]
# 23 May 15:41    INFO  epoch 3 training [time: 0.19s, train loss: 7.9576]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  75%|██████████████████████████████████▋           | 356/472 [00:00<00:00, 3554.44it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 3327.35it/s]
# 23 May 15:41    INFO  epoch 3 evaluating [time: 0.15s, valid_score: 0.343100]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.182    mrr@10 : 0.3431    ndcg@10 : 0.1981    hit@10 : 0.6893    precision@10 : 0.1393
# 23 May 15:41    INFO  Saving current: saved/BPR-May-23-2024_15-41-36.pth
# Train     4:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  65%|███████████████████████████████▊                 | 26/40 [00:00<00:00, 257.23it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 270.88it/s]
# 23 May 15:41    INFO  epoch 4 training [time: 0.15s, train loss: 7.1204]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  64%|█████████████████████████████▌                | 303/472 [00:00<00:00, 3029.60it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 3111.05it/s]
# 23 May 15:41    INFO  epoch 4 evaluating [time: 0.16s, valid_score: 0.343500]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1842    mrr@10 : 0.3435    ndcg@10 : 0.1991    hit@10 : 0.6925    precision@10 : 0.1407
# 23 May 15:41    INFO  Saving current: saved/BPR-May-23-2024_15-41-36.pth
# Train     5:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  50%|████████████████████████▌                        | 20/40 [00:00<00:00, 191.36it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 207.89it/s]
# 23 May 15:41    INFO  epoch 5 training [time: 0.20s, train loss: 6.1491]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  58%|██████████████████████████▋                   | 274/472 [00:00<00:00, 2731.74it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2753.77it/s]
# 23 May 15:41    INFO  epoch 5 evaluating [time: 0.18s, valid_score: 0.341000]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1826    mrr@10 : 0.341    ndcg@10 : 0.1992    hit@10 : 0.7041    precision@10 : 0.141
# Train     6:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  52%|█████████████████████████▋                       | 21/40 [00:00<00:00, 202.97it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 201.69it/s]
# 23 May 15:41    INFO  epoch 6 training [time: 0.20s, train loss: 5.5717]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  58%|██████████████████████████▊                   | 275/472 [00:00<00:00, 2745.92it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2734.63it/s]
# 23 May 15:41    INFO  epoch 6 evaluating [time: 0.18s, valid_score: 0.336300]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1867    mrr@10 : 0.3363    ndcg@10 : 0.1983    hit@10 : 0.7105    precision@10 : 0.1411
# Train     7:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  50%|████████████████████████▌                        | 20/40 [00:00<00:00, 194.46it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 194.38it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 192.52it/s]
# 23 May 15:41    INFO  epoch 7 training [time: 0.21s, train loss: 5.0738]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  56%|█████████████████████████▋                    | 264/472 [00:00<00:00, 2630.48it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2601.82it/s]
# 23 May 15:41    INFO  epoch 7 evaluating [time: 0.19s, valid_score: 0.350800]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1929    mrr@10 : 0.3508    ndcg@10 : 0.2041    hit@10 : 0.7179    precision@10 : 0.142
# 23 May 15:41    INFO  Saving current: saved/BPR-May-23-2024_15-41-36.pth
# Train     8:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  57%|████████████████████████████▏                    | 23/40 [00:00<00:00, 223.75it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 224.55it/s]
# 23 May 15:41    INFO  epoch 8 training [time: 0.18s, train loss: 4.6037]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  65%|██████████████████████████████                | 309/472 [00:00<00:00, 3088.17it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 3060.97it/s]
# 23 May 15:41    INFO  epoch 8 evaluating [time: 0.16s, valid_score: 0.339100]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1849    mrr@10 : 0.3391    ndcg@10 : 0.1985    hit@10 : 0.6988    precision@10 : 0.1417
# Train     9:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  62%|██████████████████████████████▋                  | 25/40 [00:00<00:00, 244.11it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 231.18it/s]
# 23 May 15:41    INFO  epoch 9 training [time: 0.18s, train loss: 4.3014]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  62%|████████████████████████████▌                 | 293/472 [00:00<00:00, 2922.10it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2920.41it/s]
# 23 May 15:41    INFO  epoch 9 evaluating [time: 0.17s, valid_score: 0.330500]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1858    mrr@10 : 0.3305    ndcg@10 : 0.1956    hit@10 : 0.7041    precision@10 : 0.1392
# Train    10:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  55%|██████████████████████████▉                      | 22/40 [00:00<00:00, 212.39it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 236.46it/s]
# 23 May 15:41    INFO  epoch 10 training [time: 0.17s, train loss: 3.9565]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  61%|███████████████████████████▊                  | 286/472 [00:00<00:00, 2855.92it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2818.25it/s]
# 23 May 15:41    INFO  epoch 10 evaluating [time: 0.18s, valid_score: 0.334000]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1826    mrr@10 : 0.334    ndcg@10 : 0.1949    hit@10 : 0.7031    precision@10 : 0.1372
# Train    11:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  55%|██████████████████████████▉                      | 22/40 [00:00<00:00, 212.45it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 206.25it/s]
# 23 May 15:41    INFO  epoch 11 training [time: 0.20s, train loss: 3.7091]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  53%|████████████████████████▎                     | 250/472 [00:00<00:00, 2493.87it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2614.63it/s]
# 23 May 15:41    INFO  epoch 11 evaluating [time: 0.19s, valid_score: 0.343500]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1914    mrr@10 : 0.3435    ndcg@10 : 0.2007    hit@10 : 0.7179    precision@10 : 0.1401
# Train    12:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  52%|█████████████████████████▋                       | 21/40 [00:00<00:00, 206.24it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 194.98it/s]
# 23 May 15:41    INFO  epoch 12 training [time: 0.21s, train loss: 3.4709]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  69%|███████████████████████████████▊              | 327/472 [00:00<00:00, 3263.38it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 3129.14it/s]
# 23 May 15:41    INFO  epoch 12 evaluating [time: 0.16s, valid_score: 0.339800]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1898    mrr@10 : 0.3398    ndcg@10 : 0.1979    hit@10 : 0.7158    precision@10 : 0.1359
# Train    13:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  55%|██████████████████████████▉                      | 22/40 [00:00<00:00, 217.63it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 207.64it/s]
# 23 May 15:41    INFO  epoch 13 training [time: 0.20s, train loss: 3.2957]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  59%|███████████████████████████                   | 278/472 [00:00<00:00, 2777.72it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2799.60it/s]
# 23 May 15:41    INFO  epoch 13 evaluating [time: 0.18s, valid_score: 0.340200]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1909    mrr@10 : 0.3402    ndcg@10 : 0.1982    hit@10 : 0.7169    precision@10 : 0.1368
# Train    14:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  55%|██████████████████████████▉                      | 22/40 [00:00<00:00, 212.18it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 210.28it/s]
# 23 May 15:41    INFO  epoch 14 training [time: 0.19s, train loss: 3.1316]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  61%|███████████████████████████▉                  | 287/472 [00:00<00:00, 2866.52it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2887.26it/s]
# 23 May 15:41    INFO  epoch 14 evaluating [time: 0.17s, valid_score: 0.343400]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1879    mrr@10 : 0.3434    ndcg@10 : 0.1959    hit@10 : 0.7031    precision@10 : 0.1335
# Train    15:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  57%|████████████████████████████▏                    | 23/40 [00:00<00:00, 220.19it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 205.62it/s]
# 23 May 15:41    INFO  epoch 15 training [time: 0.20s, train loss: 3.0091]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  64%|█████████████████████████████▍                | 302/472 [00:00<00:00, 3015.76it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 3028.33it/s]
# 23 May 15:41    INFO  epoch 15 evaluating [time: 0.17s, valid_score: 0.330700]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1785    mrr@10 : 0.3307    ndcg@10 : 0.1868    hit@10 : 0.6861    precision@10 : 0.1278
# Train    16:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  60%|█████████████████████████████▍                   | 24/40 [00:00<00:00, 238.98it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 249.88it/s]
# 23 May 15:41    INFO  epoch 16 training [time: 0.16s, train loss: 2.8710]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  56%|█████████████████████████▊                    | 265/472 [00:00<00:00, 2648.06it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2664.32it/s]
# 23 May 15:41    INFO  epoch 16 evaluating [time: 0.19s, valid_score: 0.328500]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1775    mrr@10 : 0.3285    ndcg@10 : 0.1832    hit@10 : 0.6893    precision@10 : 0.1275
# Train    17:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  60%|█████████████████████████████▍                   | 24/40 [00:00<00:00, 235.39it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 223.03it/s]
# 23 May 15:41    INFO  epoch 17 training [time: 0.18s, train loss: 2.7255]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  61%|███████████████████████████▉                  | 287/472 [00:00<00:00, 2861.59it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2860.92it/s]
# 23 May 15:41    INFO  epoch 17 evaluating [time: 0.18s, valid_score: 0.330300]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1825    mrr@10 : 0.3303    ndcg@10 : 0.1858    hit@10 : 0.6957    precision@10 : 0.1282
# Train    18:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  50%|████████████████████████▌                        | 20/40 [00:00<00:00, 198.68it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 207.40it/s]
# 23 May 15:41    INFO  epoch 18 training [time: 0.20s, train loss: 2.5715]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  59%|██████████████████████████▉                   | 277/472 [00:00<00:00, 2762.98it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2673.26it/s]
# 23 May 15:41    INFO  epoch 18 evaluating [time: 0.19s, valid_score: 0.321600]
# 23 May 15:41    INFO  valid result:
# recall@10 : 0.1792    mrr@10 : 0.3216    ndcg@10 : 0.1845    hit@10 : 0.6829    precision@10 : 0.1269
# 23 May 15:41    INFO  Finished training, best eval result in epoch 7
# 23 May 15:41    INFO  Loading model structure and parameters from saved/BPR-May-23-2024_15-41-36.pth
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  66%|██████████████████████████████▏               | 310/472 [00:00<00:00, 3094.31it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 3017.62it/s]
# 23 May 15:41    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |    36.10 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.51 G/13.86 G |
# +-------------+----------------+
# 23 May 15:41    INFO  best valid : OrderedDict([('recall@10', 0.1929), ('mrr@10', 0.3508), ('ndcg@10', 0.2041), ('hit@10', 0.7179), ('precision@10', 0.142)])
# 23 May 15:41    INFO  test result: OrderedDict([('recall@10', 0.2092), ('mrr@10', 0.4297), ('ndcg@10', 0.2439), ('hit@10', 0.7519), ('precision@10', 0.1637)])
# {'best_valid_score': 0.3508,
#  'valid_score_bigger': True,
#  'best_valid_result': OrderedDict([('recall@10', 0.1929),
#               ('mrr@10', 0.3508),
#               ('ndcg@10', 0.2041),
#               ('hit@10', 0.7179),
#               ('precision@10', 0.142)]),
#  'test_result': OrderedDict([('recall@10', 0.2092),
#               ('mrr@10', 0.4297),
#               ('ndcg@10', 0.2439),
#               ('hit@10', 0.7519),
#               ('precision@10', 0.1637)])}

# %%
import pandas as pd
from recbole.quick_start import run_recbole

# Load the data
data = pd.read_csv('u.data', sep='\t', names=['user_id', 'item_id', 'rating', 'timestamp'])

# Convert all ratings to 1
data['rating'] = 1  # Set all ratings to 1

# Save binary data
data.to_csv('dataset/ml100k_always_implicit/ml100k_always_implicit.inter', index=False, sep='\t', header=['user_id:token', 'item_id:token', 'rating:float', 'timestamp:float'])

# Configuration for running BPR
config_dict_implicit = {
    'model': 'BPR',
    'dataset': 'ml100k_always_implicit',
    'learning_rate': 0.01,
    'epochs': 100,
    'embedding_size': 64,
    'eval_setting': 'RO_RS',
    'metrics': ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision'],
    'valid_metric': 'MRR@10',
    'topk': 10,
    'gpu_id': 0,
    'early_stop': 5,
}

# Run the model for implicit feedback where all interactions are positive
run_recbole(model='BPR', dataset='ml100k_always_implicit', config_dict=config_dict_implicit)
# Out:
# 23 May 15:43    INFO  ['/home/stef/.local/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/home/stef/.local/share/jupyter/runtime/kernel-510548df-5f9c-4af3-8da9-9e6950dbae6c.json']
# 23 May 15:43    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/ml100k_always_implicit
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.01
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# eval_setting = RO_RS
# early_stop = 5
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# /home/stef/.local/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# 23 May 15:43    INFO  ml100k_always_implicit
# The number of users: 944
# Average actions of users: 106.04453870625663
# The number of items: 1683
# Average actions of items: 59.45303210463734
# The number of inters: 100000
# The sparsity of the dataset: 93.70575143257098%
# Remain Fields: ['user_id', 'item_id']
# 23 May 15:43    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 23 May 15:43    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 23 May 15:43    INFO  BPR(
#   (user_embedding): Embedding(944, 64)
#   (item_embedding): Embedding(1683, 64)
#   (loss): BPRLoss()
# )
# Trainable parameters: 168128
# 23 May 15:43    INFO  FLOPs: 128.0
# Train     0:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  60%|█████████████████████████████▍                   | 24/40 [00:00<00:00, 236.34it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 202.95it/s]
# 23 May 15:43    INFO  epoch 0 training [time: 0.20s, train loss: 25.2600]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  45%|████████████████████▊                         | 213/472 [00:00<00:00, 2127.60it/s]:  90%|█████████████████████████████████████████▌    | 426/472 [00:00<00:00, 2122.51it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2067.51it/s]
# 23 May 15:43    INFO  epoch 0 evaluating [time: 0.24s, valid_score: 0.263900]
# 23 May 15:43    INFO  valid result:
# recall@10 : 0.1154    mrr@10 : 0.2639    ndcg@10 : 0.1371    hit@10 : 0.5525    precision@10 : 0.1011
# 23 May 15:43    INFO  Saving current: saved/BPR-May-23-2024_15-43-10.pth
# Train     1:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  55%|██████████████████████████▉                      | 22/40 [00:00<00:00, 214.40it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 195.81it/s]
# 23 May 15:43    INFO  epoch 1 training [time: 0.21s, train loss: 13.0037]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  56%|█████████████████████████▉                    | 266/472 [00:00<00:00, 2651.87it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2545.27it/s]
# 23 May 15:43    INFO  epoch 1 evaluating [time: 0.20s, valid_score: 0.308100]
# 23 May 15:43    INFO  valid result:
# recall@10 : 0.1488    mrr@10 : 0.3081    ndcg@10 : 0.1682    hit@10 : 0.6278    precision@10 : 0.1144
# 23 May 15:43    INFO  Saving current: saved/BPR-May-23-2024_15-43-10.pth
# Train     2:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  52%|█████████████████████████▋                       | 21/40 [00:00<00:00, 207.72it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 192.57it/s]
# 23 May 15:43    INFO  epoch 2 training [time: 0.21s, train loss: 9.8429]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  61%|████████████████████████████▏                 | 289/472 [00:00<00:00, 2879.77it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2818.75it/s]
# 23 May 15:43    INFO  epoch 2 evaluating [time: 0.18s, valid_score: 0.319100]
# 23 May 15:43    INFO  valid result:
# recall@10 : 0.1779    mrr@10 : 0.3191    ndcg@10 : 0.1892    hit@10 : 0.6797    precision@10 : 0.1334
# 23 May 15:43    INFO  Saving current: saved/BPR-May-23-2024_15-43-10.pth
# Train     3:   0%|                                                           | 0/40 [00:00<?, ?it/s]:
   0%|                                                           | 0/40 [00:00<?, ?it/s]:  10%|█████                                              | 4/40 [00:00<00:00, 39.87it/s]:  68%|█████████████████████████████████                | 27/40 [00:00<00:00, 148.15it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 144.92it/s]
# 23 May 15:43    INFO  epoch 14 training [time: 0.28s, train loss: 3.1316]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  62%|████████████████████████████▍                 | 292/472 [00:00<00:00, 2914.17it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2846.23it/s]
# 23 May 15:43    INFO  epoch 14 evaluating [time: 0.18s, valid_score: 0.343400]
# 23 May 15:43    INFO  valid result:
# recall@10 : 0.1879    mrr@10 : 0.3434    ndcg@10 : 0.1959    hit@10 : 0.7031    precision@10 : 0.1335
# Train    15:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  48%|███████████████████████▎                         | 19/40 [00:00<00:00, 187.44it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 205.35it/s]
# 23 May 15:43    INFO  epoch 15 training [time: 0.20s, train loss: 3.0091]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  55%|█████████████████████████▏                    | 259/472 [00:00<00:00, 2588.71it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2602.49it/s]
# 23 May 15:43    INFO  epoch 15 evaluating [time: 0.19s, valid_score: 0.330700]
# 23 May 15:43    INFO  valid result:
# recall@10 : 0.1785    mrr@10 : 0.3307    ndcg@10 : 0.1868    hit@10 : 0.6861    precision@10 : 0.1278
# Train    16:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  48%|███████████████████████▎                         | 19/40 [00:00<00:00, 182.81it/s]:  95%|██████████████████████████████████████████████▌  | 38/40 [00:00<00:00, 183.42it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 179.56it/s]
# 23 May 15:43    INFO  epoch 16 training [time: 0.23s, train loss: 2.8710]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  58%|██████████████████████████▊                   | 275/472 [00:00<00:00, 2745.66it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2862.52it/s]
# 23 May 15:43    INFO  epoch 16 evaluating [time: 0.18s, valid_score: 0.328500]
# 23 May 15:43    INFO  valid result:
# recall@10 : 0.1775    mrr@10 : 0.3285    ndcg@10 : 0.1832    hit@10 : 0.6893    precision@10 : 0.1275
# Train    17:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  48%|███████████████████████▎                         | 19/40 [00:00<00:00, 185.51it/s]:  95%|██████████████████████████████████████████████▌  | 38/40 [00:00<00:00, 187.24it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 182.62it/s]
# 23 May 15:43    INFO  epoch 17 training [time: 0.23s, train loss: 2.7255]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  56%|█████████████████████████▋                    | 264/472 [00:00<00:00, 2639.45it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2810.35it/s]
# 23 May 15:43    INFO  epoch 17 evaluating [time: 0.18s, valid_score: 0.330300]
# 23 May 15:43    INFO  valid result:
# recall@10 : 0.1825    mrr@10 : 0.3303    ndcg@10 : 0.1858    hit@10 : 0.6957    precision@10 : 0.1282
# Train    18:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  75%|████████████████████████████████████▊            | 30/40 [00:00<00:00, 292.87it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 264.14it/s]
# 23 May 15:43    INFO  epoch 18 training [time: 0.16s, train loss: 2.5715]
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  59%|██████████████████████████▉                   | 277/472 [00:00<00:00, 2765.16it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2631.91it/s]
# 23 May 15:43    INFO  epoch 18 evaluating [time: 0.19s, valid_score: 0.321600]
# 23 May 15:43    INFO  valid result:
# recall@10 : 0.1792    mrr@10 : 0.3216    ndcg@10 : 0.1845    hit@10 : 0.6829    precision@10 : 0.1269
# 23 May 15:43    INFO  Finished training, best eval result in epoch 7
# 23 May 15:43    INFO  Loading model structure and parameters from saved/BPR-May-23-2024_15-43-10.pth
# Evaluate   :   0%|                                                          | 0/472 [00:00<?, ?it/s]:  49%|██████████████████████▌                       | 231/472 [00:00<00:00, 2308.76it/s]:  99%|█████████████████████████████████████████████▌| 468/472 [00:00<00:00, 2343.92it/s]: 100%|██████████████████████████████████████████████| 472/472 [00:00<00:00, 2297.99it/s]
# 23 May 15:43    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |    29.50 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.53 G/13.86 G |
# +-------------+----------------+
# 23 May 15:43    INFO  best valid : OrderedDict([('recall@10', 0.1929), ('mrr@10', 0.3508), ('ndcg@10', 0.2041), ('hit@10', 0.7179), ('precision@10', 0.142)])
# 23 May 15:43    INFO  test result: OrderedDict([('recall@10', 0.2092), ('mrr@10', 0.4297), ('ndcg@10', 0.2439), ('hit@10', 0.7519), ('precision@10', 0.1637)])
# {'best_valid_score': 0.3508,
#  'valid_score_bigger': True,
#  'best_valid_result': OrderedDict([('recall@10', 0.1929),
#               ('mrr@10', 0.3508),
#               ('ndcg@10', 0.2041),
#               ('hit@10', 0.7179),
#               ('precision@10', 0.142)]),
#  'test_result': OrderedDict([('recall@10', 0.2092),
#               ('mrr@10', 0.4297),
#               ('ndcg@10', 0.2439),
#               ('hit@10', 0.7519),
#               ('precision@10', 0.1637)])}

# %% [markdown]
# 2. **FM**:
# The next experiment tests Factorization Machines (FMs) for both implicit and explicit feedback datasets using RecBole. A key issue encountered was the incompatibility of using top-k evaluation metrics with the FM model. This problem stems from the nature of the FM model in RecBole, which is primarily designed for prediction tasks, not ranking tasks typically assessed by top-k metrics. This mismatch led to difficulties in directly applying top-k evaluations such as Recall, Precision, and NDCG without adjustments or different model configurations that support such metrics. This issue was consistent across both implicit and explicit feedback models, indicating a broader limitation with the FM implementation in RecBole for ranking-based evaluations.

# %%
import pandas as pd
from recbole.quick_start import run_recbole

# Load data and normalize ratings for explicit feedback
data = pd.read_csv('u.data', sep='\t', names=['user_id', 'item_id', 'rating', 'timestamp'])
max_rating = data['rating'].max()
data['rating'] = data['rating'] / max_rating

# Save the data with simple headers
data.to_csv('dataset/ml100k_explicit_fm/ml100k_explicit_fm.inter', index=False, sep='\t',
            header=['user_id:token', 'item_id:token', 'rating:float', 'timestamp:float'])

# Configuration for FM with explicit feedback
config_dict_explicit = {
    'model': 'FM',
    'dataset': 'ml100k_explicit_fm',
    'epochs': 100,
    'learning_rate': 0.01,
    'eval_setting': 'RO_RS',  # Random Ordering, Random Splitting
    'metrics': ['RMSE', 'MAE'],  # Evaluation metrics suitable for binary classification
    'valid_metric': 'RMSE',  # Main metric for validation
    'topk': 10,
    'early_stop': 5,
    'gpu_id': 0,
    'LABEL_FIELD': 'rating',  # This must match exactly with your data headers
    'load_col': {'inter': ['user_id', 'item_id', 'rating', 'timestamp']}
}

# Run the model
run_recbole(model='FM', dataset='ml100k_explicit_fm', config_dict=config_dict_explicit)
# Out:
# 23 May 15:47    INFO  ['/home/stef/.local/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/home/stef/.local/share/jupyter/runtime/kernel-510548df-5f9c-4af3-8da9-9e6950dbae6c.json']
# 23 May 15:47    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/ml100k_explicit_fm
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.01
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': None, 'mode': {'valid': 'labeled', 'test': 'labeled'}}
# repeatable = False
# metrics = ['RMSE', 'MAE']
# topk = [10]
# valid_metric = RMSE
# valid_metric_bigger = False
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = rating
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'rating', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 10
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.CONTEXT
# eval_setting = RO_RS
# early_stop = 5
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.VALUE
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'none', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'none', 'sample_num': 'none'}
#
#
# /home/stef/.local/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# /home/stef/.local/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:650: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=feat[field].mean(), inplace=True)
# 23 May 15:47    INFO  ml100k_explicit_fm
# The number of users: 944
# Average actions of users: 106.04453870625663
# The number of items: 1683
# Average actions of items: 59.45303210463734
# The number of inters: 100000
# The sparsity of the dataset: 93.70575143257098%
# Remain Fields: ['user_id', 'item_id', 'rating', 'timestamp']
# 23 May 15:47    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# 23 May 15:47    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': None, 'mode': {'valid': 'labeled', 'test': 'labeled'}}]
# 23 May 15:47    INFO  FM(
#   (token_embedding_table): FMEmbedding(
#     (embedding): Embedding(2627, 10)
#   )
#   (first_order_linear): FMFirstOrderLinear(
#     (token_embedding_table): FMEmbedding(
#       (embedding): Embedding(2627, 1)
#     )
#   )
#   (fm): BaseFactorizationMachine()
#   (sigmoid): Sigmoid()
#   (loss): BCEWithLogitsLoss()
# )
# Trainable parameters: 28898
# 23 May 15:47    INFO  FLOPs: 22.0
# Train     0:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  45%|██████████████████████                           | 18/40 [00:00<00:00, 178.02it/s]:  92%|█████████████████████████████████████████████▎   | 37/40 [00:00<00:00, 183.11it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 180.11it/s]
# 23 May 15:48    INFO  epoch 0 training [time: 0.23s, train loss: 25.0502]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 282.06it/s]
# 23 May 15:48    INFO  epoch 0 evaluating [time: 0.02s, valid_score: 0.206000]
# 23 May 15:48    INFO  valid result:
# rmse : 0.206    mae : 0.1708
# 23 May 15:48    INFO  Saving current: saved/FM-May-23-2024_15-47-59.pth
# Train     1:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  60%|█████████████████████████████▍                   | 24/40 [00:00<00:00, 235.61it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 225.03it/s]
# 23 May 15:48    INFO  epoch 1 training [time: 0.19s, train loss: 22.8312]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 230.46it/s]
# 23 May 15:48    INFO  epoch 1 evaluating [time: 0.02s, valid_score: 0.189300]
# 23 May 15:48    INFO  valid result:
# rmse : 0.1893    mae : 0.1506
# 23 May 15:48    INFO  Saving current: saved/FM-May-23-2024_15-47-59.pth
# Train     2:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  48%|███████████████████████▎                         | 19/40 [00:00<00:00, 184.38it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 205.33it/s]
# 23 May 15:48    INFO  epoch 2 training [time: 0.21s, train loss: 22.2874]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 240.47it/s]
# 23 May 15:48    INFO  epoch 2 evaluating [time: 0.02s, valid_score: 0.184200]
# 23 May 15:48    INFO  valid result:
# rmse : 0.1842    mae : 0.1456
# 23 May 15:48    INFO  Saving current: saved/FM-May-23-2024_15-47-59.pth
# Train     3:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  55%|██████████████████████████▉                      | 22/40 [00:00<00:00, 214.04it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 205.03it/s]
# 23 May 15:48    INFO  epoch 3 training [time: 0.20s, train loss: 21.9976]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 229.63it/s]
# 23 May 15:48    INFO  epoch 3 evaluating [time: 0.02s, valid_score: 0.183500]
# 23 May 15:48    INFO  valid result:
# rmse : 0.1835    mae : 0.1445
# 23 May 15:48    INFO  Saving current: saved/FM-May-23-2024_15-47-59.pth
# Train     4:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  55%|██████████████████████████▉                      | 22/40 [00:00<00:00, 211.57it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 187.68it/s]
# 23 May 15:48    INFO  epoch 4 training [time: 0.22s, train loss: 21.7809]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 266.10it/s]
# 23 May 15:48    INFO  epoch 4 evaluating [time: 0.02s, valid_score: 0.184300]
# 23 May 15:48    INFO  valid result:
# rmse : 0.1843    mae : 0.1449
# Train     5:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  68%|█████████████████████████████████                | 27/40 [00:00<00:00, 267.80it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 255.64it/s]
# 23 May 15:48    INFO  epoch 5 training [time: 0.17s, train loss: 21.6283]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 235.90it/s]
# 23 May 15:48    INFO  epoch 5 evaluating [time: 0.02s, valid_score: 0.185600]
# 23 May 15:48    INFO  valid result:
# rmse : 0.1856    mae : 0.1455
# Train     6:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  65%|███████████████████████████████▊                 | 26/40 [00:00<00:00, 253.30it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 245.11it/s]
# 23 May 15:48    INFO  epoch 6 training [time: 0.17s, train loss: 21.4991]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 248.24it/s]
# 23 May 15:48    INFO  epoch 6 evaluating [time: 0.02s, valid_score: 0.187000]
# 23 May 15:48    INFO  valid result:
# rmse : 0.187    mae : 0.1465
# Train     7:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  80%|███████████████████████████████████████▏         | 32/40 [00:00<00:00, 309.16it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 278.51it/s]
# 23 May 15:48    INFO  epoch 7 training [time: 0.15s, train loss: 21.4205]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 262.03it/s]
# 23 May 15:48    INFO  epoch 7 evaluating [time: 0.02s, valid_score: 0.188300]
# 23 May 15:48    INFO  valid result:
# rmse : 0.1883    mae : 0.1472
# Train     8:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  55%|██████████████████████████▉                      | 22/40 [00:00<00:00, 208.99it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 203.88it/s]
# 23 May 15:48    INFO  epoch 8 training [time: 0.21s, train loss: 21.3068]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 181.57it/s]
# 23 May 15:48    INFO  epoch 8 evaluating [time: 0.03s, valid_score: 0.189800]
# 23 May 15:48    INFO  valid result:
# rmse : 0.1898    mae : 0.1481
# Train     9:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  57%|████████████████████████████▏                    | 23/40 [00:00<00:00, 227.35it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 217.90it/s]
# 23 May 15:48    INFO  epoch 9 training [time: 0.19s, train loss: 21.2529]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 208.41it/s]
# 23 May 15:48    INFO  epoch 9 evaluating [time: 0.02s, valid_score: 0.191200]
# 23 May 15:48    INFO  valid result:
# rmse : 0.1912    mae : 0.1489
# Train    10:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  62%|██████████████████████████████▋                  | 25/40 [00:00<00:00, 245.73it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 219.62it/s]
# 23 May 15:48    INFO  epoch 10 training [time: 0.19s, train loss: 21.2084]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 155.22it/s]
# 23 May 15:48    INFO  epoch 10 evaluating [time: 0.03s, valid_score: 0.192700]
# 23 May 15:48    INFO  valid result:
# rmse : 0.1927    mae : 0.1498
# Train    11:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  57%|████████████████████████████▏                    | 23/40 [00:00<00:00, 221.69it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 225.22it/s]
# 23 May 15:48    INFO  epoch 11 training [time: 0.19s, train loss: 21.1674]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 270.90it/s]
# 23 May 15:48    INFO  epoch 11 evaluating [time: 0.02s, valid_score: 0.194100]
# 23 May 15:48    INFO  valid result:
# rmse : 0.1941    mae : 0.1507
# Train    12:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  57%|████████████████████████████▏                    | 23/40 [00:00<00:00, 225.19it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 200.18it/s]
# 23 May 15:48    INFO  epoch 12 training [time: 0.21s, train loss: 21.1525]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 288.30it/s]
# 23 May 15:48    INFO  epoch 12 evaluating [time: 0.02s, valid_score: 0.195000]
# 23 May 15:48    INFO  valid result:
# rmse : 0.195    mae : 0.1513
# Train    13:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  60%|█████████████████████████████▍                   | 24/40 [00:00<00:00, 239.03it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 269.93it/s]
# 23 May 15:48    INFO  epoch 13 training [time: 0.16s, train loss: 21.0953]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 292.90it/s]
# 23 May 15:48    INFO  epoch 13 evaluating [time: 0.02s, valid_score: 0.195900]
# 23 May 15:48    INFO  valid result:
# rmse : 0.1959    mae : 0.1517
# Train    14:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  62%|██████████████████████████████▋                  | 25/40 [00:00<00:00, 245.05it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 230.95it/s]
# 23 May 15:48    INFO  epoch 14 training [time: 0.18s, train loss: 21.0832]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 256.33it/s]
# 23 May 15:48    INFO  epoch 14 evaluating [time: 0.02s, valid_score: 0.196900]
# 23 May 15:48    INFO  valid result:
# rmse : 0.1969    mae : 0.1523
# 23 May 15:48    INFO  Finished training, best eval result in epoch 3
# 23 May 15:48    INFO  Loading model structure and parameters from saved/FM-May-23-2024_15-47-59.pth
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 255.49it/s]
# 23 May 15:48    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |    33.30 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.54 G/13.86 G |
# +-------------+----------------+
# 23 May 15:48    INFO  best valid : OrderedDict([('rmse', 0.1835), ('mae', 0.1445)])
# 23 May 15:48    INFO  test result: OrderedDict([('rmse', 0.1847), ('mae', 0.1457)])
# {'best_valid_score': 0.1835,
#  'valid_score_bigger': False,
#  'best_valid_result': OrderedDict([('rmse', 0.1835), ('mae', 0.1445)]),
#  'test_result': OrderedDict([('rmse', 0.1847), ('mae', 0.1457)])}

# %%
import pandas as pd
from recbole.quick_start import run_recbole

# Load data and treat any rating as an interaction (implicit feedback)
data = pd.read_csv('u.data', sep='\t', names=['user_id', 'item_id', 'rating', 'timestamp'])
data['rating'] = (data['rating'] > 0).astype(int)  # Convert ratings to 1 to denote interaction

# Save the data with simple headers
data.to_csv('dataset/ml100k_implicit_fm/ml100k_implicit_fm.inter', index=False, sep='\t',
            header=['user_id:token', 'item_id:token', 'rating:float', 'timestamp:float'])

# Configuration for FM with implicit feedback
config_dict_implicit = {
    'model': 'FM',
    'dataset': 'ml100k_implicit_fm',
    'epochs': 100,
    'learning_rate': 0.01,
    'eval_setting': 'RO_RS',  # Random Ordering, Random Splitting
    'metrics': ['RMSE', 'MAE'],  # Evaluation metrics suitable for binary classification
    'valid_metric': 'RMSE',  # Main metric for validation
    'topk': 10,
    'early_stop': 5,
    'gpu_id': 0,
    'LABEL_FIELD': 'rating',  # This must match exactly with your data headers
    'load_col': {'inter': ['user_id', 'item_id', 'rating', 'timestamp']}
}

# Run the model
run_recbole(model='FM', dataset='ml100k_implicit_fm', config_dict=config_dict_implicit)
# Out:
# 23 May 15:48    INFO  ['/home/stef/.local/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/home/stef/.local/share/jupyter/runtime/kernel-510548df-5f9c-4af3-8da9-9e6950dbae6c.json']
# 23 May 15:48    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/ml100k_implicit_fm
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.01
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': None, 'mode': {'valid': 'labeled', 'test': 'labeled'}}
# repeatable = False
# metrics = ['RMSE', 'MAE']
# topk = [10]
# valid_metric = RMSE
# valid_metric_bigger = False
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = rating
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'rating', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 10
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.CONTEXT
# eval_setting = RO_RS
# early_stop = 5
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.VALUE
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'none', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'none', 'sample_num': 'none'}
#
#
# /home/stef/.local/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# /home/stef/.local/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:650: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=feat[field].mean(), inplace=True)
# 23 May 15:48    INFO  ml100k_implicit_fm
# The number of users: 944
# Average actions of users: 106.04453870625663
# The number of items: 1683
# Average actions of items: 59.45303210463734
# The number of inters: 100000
# The sparsity of the dataset: 93.70575143257098%
# Remain Fields: ['user_id', 'item_id', 'rating', 'timestamp']
# 23 May 15:48    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# 23 May 15:48    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': None, 'mode': {'valid': 'labeled', 'test': 'labeled'}}]
# 23 May 15:48    INFO  FM(
#   (token_embedding_table): FMEmbedding(
#     (embedding): Embedding(2627, 10)
#   )
#   (first_order_linear): FMFirstOrderLinear(
#     (token_embedding_table): FMEmbedding(
#       (embedding): Embedding(2627, 1)
#     )
#   )
#   (fm): BaseFactorizationMachine()
#   (sigmoid): Sigmoid()
#   (loss): BCEWithLogitsLoss()
# )
# Trainable parameters: 28898
# 23 May 15:48    INFO  FLOPs: 22.0
# Train     0:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  52%|█████████████████████████▋                       | 21/40 [00:00<00:00, 204.91it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 198.69it/s]
# 23 May 15:48    INFO  epoch 0 training [time: 0.21s, train loss: 18.3420]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 182.45it/s]
# 23 May 15:48    INFO  epoch 0 evaluating [time: 0.03s, valid_score: 0.200900]
# 23 May 15:48    INFO  valid result:
# rmse : 0.2009    mae : 0.1983
# 23 May 15:48    INFO  Saving current: saved/FM-May-23-2024_15-48-38.pth
# Train     1:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  55%|██████████████████████████▉                      | 22/40 [00:00<00:00, 218.35it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 212.56it/s]
# 23 May 15:48    INFO  epoch 1 training [time: 0.20s, train loss: 3.5962]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 191.93it/s]
# 23 May 15:48    INFO  epoch 1 evaluating [time: 0.03s, valid_score: 0.031600]
# 23 May 15:48    INFO  valid result:
# rmse : 0.0316    mae : 0.0233
# 23 May 15:48    INFO  Saving current: saved/FM-May-23-2024_15-48-38.pth
# Train     2:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  62%|██████████████████████████████▋                  | 25/40 [00:00<00:00, 248.73it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 258.45it/s]
# 23 May 15:48    INFO  epoch 2 training [time: 0.16s, train loss: 0.4965]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 221.19it/s]
# 23 May 15:48    INFO  epoch 2 evaluating [time: 0.02s, valid_score: 0.014400]
# 23 May 15:48    INFO  valid result:
# rmse : 0.0144    mae : 0.0073
# 23 May 15:48    INFO  Saving current: saved/FM-May-23-2024_15-48-38.pth
# Train     3:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  55%|██████████████████████████▉                      | 22/40 [00:00<00:00, 212.77it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 202.90it/s]
# 23 May 15:48    INFO  epoch 3 training [time: 0.21s, train loss: 0.1954]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 142.36it/s]
# 23 May 15:48    INFO  epoch 3 evaluating [time: 0.04s, valid_score: 0.011000]
# 23 May 15:48    INFO  valid result:
# rmse : 0.011    mae : 0.004
# 23 May 15:48    INFO  Saving current: saved/FM-May-23-2024_15-48-38.pth
# Train     4:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  65%|███████████████████████████████▊                 | 26/40 [00:00<00:00, 249.42it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 226.32it/s]
# 23 May 15:48    INFO  epoch 4 training [time: 0.19s, train loss: 0.1110]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 231.78it/s]
# 23 May 15:48    INFO  epoch 4 evaluating [time: 0.03s, valid_score: 0.009800]
# 23 May 15:48    INFO  valid result:
# rmse : 0.0098    mae : 0.0026
# 23 May 15:48    INFO  Saving current: saved/FM-May-23-2024_15-48-38.pth
# Train     5:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  55%|██████████████████████████▉                      | 22/40 [00:00<00:00, 211.45it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 230.51it/s]
# 23 May 15:48    INFO  epoch 5 training [time: 0.18s, train loss: 0.0728]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 336.87it/s]
# 23 May 15:48    INFO  epoch 5 evaluating [time: 0.02s, valid_score: 0.009300]
# 23 May 15:48    INFO  valid result:
# rmse : 0.

# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 280.33it/s]
# 23 May 15:49    INFO  epoch 94 evaluating [time: 0.02s, valid_score: 0.008200]
# 23 May 15:49    INFO  valid result:
# rmse : 0.0082    mae : 0.0003
# 23 May 15:49    INFO  Saving current: saved/FM-May-23-2024_15-48-38.pth
# Train    95:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  72%|███████████████████████████████████▌             | 29/40 [00:00<00:00, 283.89it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 268.24it/s]
# 23 May 15:49    INFO  epoch 95 training [time: 0.16s, train loss: 0.0002]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 281.96it/s]
# 23 May 15:49    INFO  epoch 95 evaluating [time: 0.02s, valid_score: 0.008200]
# 23 May 15:49    INFO  valid result:
# rmse : 0.0082    mae : 0.0003
# 23 May 15:49    INFO  Saving current: saved/FM-May-23-2024_15-48-38.pth
# Train    96:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  78%|█████████████████████████████████████▉           | 31/40 [00:00<00:00, 303.77it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 273.66it/s]
# 23 May 15:49    INFO  epoch 96 training [time: 0.16s, train loss: 0.0002]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 252.34it/s]
# 23 May 15:49    INFO  epoch 96 evaluating [time: 0.02s, valid_score: 0.008200]
# 23 May 15:49    INFO  valid result:
# rmse : 0.0082    mae : 0.0003
# 23 May 15:49    INFO  Saving current: saved/FM-May-23-2024_15-48-38.pth
# Train    97:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  48%|███████████████████████▎                         | 19/40 [00:00<00:00, 186.98it/s]:  98%|███████████████████████████████████████████████▊ | 39/40 [00:00<00:00, 193.91it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 184.92it/s]
# 23 May 15:49    INFO  epoch 97 training [time: 0.23s, train loss: 0.0002]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 272.35it/s]
# 23 May 15:49    INFO  epoch 97 evaluating [time: 0.02s, valid_score: 0.008200]
# 23 May 15:49    INFO  valid result:
# rmse : 0.0082    mae : 0.0003
# 23 May 15:49    INFO  Saving current: saved/FM-May-23-2024_15-48-38.pth
# Train    98:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  57%|████████████████████████████▏                    | 23/40 [00:00<00:00, 221.64it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 222.54it/s]
# 23 May 15:49    INFO  epoch 98 training [time: 0.19s, train loss: 0.0002]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 169.95it/s]
# 23 May 15:49    INFO  epoch 98 evaluating [time: 0.03s, valid_score: 0.008200]
# 23 May 15:49    INFO  valid result:
# rmse : 0.0082    mae : 0.0003
# 23 May 15:49    INFO  Saving current: saved/FM-May-23-2024_15-48-38.pth
# Train    99:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  57%|████████████████████████████▏                    | 23/40 [00:00<00:00, 227.12it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 242.90it/s]
# 23 May 15:49    INFO  epoch 99 training [time: 0.17s, train loss: 0.0002]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 363.19it/s]
# 23 May 15:49    INFO  epoch 99 evaluating [time: 0.02s, valid_score: 0.008200]
# 23 May 15:49    INFO  valid result:
# rmse : 0.0082    mae : 0.0003
# 23 May 15:49    INFO  Saving current: saved/FM-May-23-2024_15-48-38.pth
# 23 May 15:49    INFO  Loading model structure and parameters from saved/FM-May-23-2024_15-48-38.pth
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 266.53it/s]
# 23 May 15:49    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |    38.10 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.53 G/13.86 G |
# +-------------+----------------+
# 23 May 15:49    INFO  best valid : OrderedDict([('rmse', 0.0082), ('mae', 0.0003)])
# 23 May 15:49    INFO  test result: OrderedDict([('rmse', 0.0105), ('mae', 0.0005)])
# {'best_valid_score': 0.0082,
#  'valid_score_bigger': False,
#  'best_valid_result': OrderedDict([('rmse', 0.0082), ('mae', 0.0003)]),
#  'test_result': OrderedDict([('rmse', 0.0105), ('mae', 0.0005)])}

# %% [markdown]
# 3. **AFM**:
# The Attentional Factorization Machine (AFM) model was implemented in the RecBole framework to evaluate its performance with both explicit and implicit feedback. For explicit feedback, ratings were normalized between 0 and 1, with the model evaluated using RMSE and MAE metrics, achieving an RMSE of 0.1843 and MAE of 0.1449 on the test set. Conversely, for implicit feedback, ratings were converted to binary indicators of interaction, and the model similarly utilized RMSE and MAE for evaluation, resulting in an RMSE of 0.0119 and MAE of 0.0006.
#
# AFM incorporates attention mechanisms to prioritize significant feature interactions, providing nuanced insights into user-item relationships and demonstrating versatility in handling various feedback types by adjusting preprocessing and evaluation metrics. However, the model was not assessed using top-k ranking metrics in the explicit feedback setup, which might limit its applicability for tasks focused on ranking recommendations. Additionally, the performance sensitivity to different types of feedback suggests that further tuning might be required for optimal application in real-world scenarios, particularly when transitioning between explicit and implicit feedback settings.

# %%
import pandas as pd
from recbole.quick_start import run_recbole

# Load the data
data = pd.read_csv('u.data', sep='\t', names=['user_id', 'item_id', 'rating', 'timestamp'])

# Normalize ratings between 0 and 1
max_rating = data['rating'].max()
data['rating'] = data['rating'] / max_rating

# Save processed data for RecBole
data.to_csv('dataset/ml100k_explicit_afm/ml100k_explicit_afm.inter', index=False, sep='\t',
            header=['user_id:token', 'item_id:token', 'rating:float', 'timestamp:float'])

# Configuration for AFM with Explicit Feedback
config_dict_explicit = {
    'model': 'AFM',
    'dataset': 'ml100k_explicit_afm',
    'epochs': 100,
    'eval_setting': 'RO_RS',  # Random Ordering, Random Splitting
    'metrics': ['RMSE', 'MAE'],  # Evaluation metrics suitable for binary classification
    'valid_metric': 'RMSE',  # Main metric for validation
    'topk': 10,
    'early_stop': 5,
    'gpu_id': 0,
    'LABEL_FIELD': 'rating',
    'load_col': {'inter': ['user_id', 'item_id', 'rating', 'timestamp']},
    'neg_sampling': None,  # Make sure this is appropriate for your setup
    'ITEM_ID_FIELD': 'item_id'  # Ensuring item_id is recognized correctly
}


# Run the model
run_recbole(model='AFM', dataset='ml100k_explicit_afm', config_dict=config_dict_explicit)
# Out:
# 23 May 15:51    INFO  ['/home/stef/.local/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/home/stef/.local/share/jupyter/runtime/kernel-510548df-5f9c-4af3-8da9-9e6950dbae6c.json']
# 23 May 15:51    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/ml100k_explicit_afm
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': None, 'mode': {'valid': 'labeled', 'test': 'labeled'}}
# repeatable = False
# metrics = ['RMSE', 'MAE']
# topk = [10]
# valid_metric = RMSE
# valid_metric_bigger = False
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = rating
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'rating', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 10
# attention_size = 25
# dropout_prob = 0.3
# reg_weight = 2.0
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.CONTEXT
# eval_setting = RO_RS
# early_stop = 5
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.VALUE
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'none', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'none', 'sample_num': 'none'}
#
#
# /home/stef/.local/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# /home/stef/.local/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:650: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=feat[field].mean(), inplace=True)
# 23 May 15:51    INFO  ml100k_explicit_afm
# The number of users: 944
# Average actions of users: 106.04453870625663
# The number of items: 1683
# Average actions of items: 59.45303210463734
# The number of inters: 100000
# The sparsity of the dataset: 93.70575143257098%
# Remain Fields: ['user_id', 'item_id', 'rating', 'timestamp']
# 23 May 15:51    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# 23 May 15:51    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': None, 'mode': {'valid': 'labeled', 'test': 'labeled'}}]
# 23 May 15:51    INFO  AFM(
#   (token_embedding_table): FMEmbedding(
#     (embedding): Embedding(2627, 10)
#   )
#   (first_order_linear): FMFirstOrderLinear(
#     (token_embedding_table): FMEmbedding(
#       (embedding): Embedding(2627, 1)
#     )
#   )
#   (attlayer): AttLayer(
#     (w): Linear(in_features=10, out_features=25, bias=False)
#   )
#   (dropout_layer): Dropout(p=0.3, inplace=False)
#   (sigmoid): Sigmoid()
#   (loss): BCEWithLogitsLoss()
# )
# Trainable parameters: 29183
# 23 May 15:51    INFO  FLOPs: 272.0
# Train     0:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  32%|███████████████▉                                 | 13/40 [00:00<00:00, 128.67it/s]:  75%|████████████████████████████████████▊            | 30/40 [00:00<00:00, 152.63it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 153.47it/s]
# 23 May 15:51    INFO  epoch 0 training [time: 0.27s, train loss: 311.7857]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 221.18it/s]
# 23 May 15:51    INFO  epoch 0 evaluating [time: 0.03s, valid_score: 0.287300]
# 23 May 15:51    INFO  valid result:
# rmse : 0.2873    mae : 0.2479
# 23 May 15:51    INFO  Saving current: saved/AFM-May-23-2024_15-51-17.pth
# Train     1:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  57%|████████████████████████████▏                    | 23/40 [00:00<00:00, 219.49it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 202.31it/s]
# 23 May 15:51    INFO  epoch 1 training [time: 0.21s, train loss: 273.6113]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 291.61it/s]
# 23 May 15:51    INFO  epoch 1 evaluating [time: 0.02s, valid_score: 0.273100]
# 23 May 15:51    INFO  valid result:
# rmse : 0.2731    mae : 0.2331
# 23 May 15:51    INFO  Saving current: saved/AFM-May-23-2024_15-51-17.pth
# Train     2:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  48%|███████████████████████▎                         | 19/40 [00:00<00:00, 183.04it/s]:  95%|██████████████████████████████████████████████▌  | 38/40 [00:00<00:00, 180.51it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 178.82it/s]
# 23 May 15:51    INFO  epoch 2 training [time: 0.23s, train loss: 238.8282]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 322.24it/s]
# 23 May 15:51    INFO  epoch 2 evaluating [time: 0.02s, valid_score: 0.260200]
# 23 May 15:51    INFO  valid result:
# rmse : 0.2602    mae : 0.2188
# 23 May 15:51    INFO  Saving current: saved/AFM-May-23-2024_15-51-17.pth
# Train     3:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  42%|████████████████████▊                            | 17/40 [00:00<00:00, 160.64it/s]:  85%|█████████████████████████████████████████▋       | 34/40 [00:00<00:00, 129.01it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 132.70it/s]
# 23 May 15:51    INFO  epoch 3 training [time: 0.31s, train loss: 206.9634]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 252.42it/s]
# 23 May 15:51    INFO  epoch 3 evaluating [time: 0.02s, valid_score: 0.247200]
# 23 May 15:51    INFO  valid result:
# rmse : 0.2472    mae : 0.2042
# 23 May 15:51    INFO  Saving current: saved/AFM-May-23-2024_15-51-17.pth
# Train     4:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  50%|████████████████████████▌                        | 20/40 [00:00<00:00, 195.74it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 179.93it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 178.79it/s]
# 23 May 15:51    INFO  epoch 4 training [time: 0.23s, train loss: 177.6313]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 264.03it/s]
# 23 May 15:51    INFO  epoch 4 evaluating [time: 0.02s, valid_score: 0.233100]
# 23 May 15:51    INFO  valid result:
# rmse : 0.2331    mae : 0.1925
# 23 May 15:51    INFO  Saving current: saved/AFM-May-23-2024_15-51-17.pth
# Train     5:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  42%|████████████████████▊                            | 17/40 [00:00<00:00, 167.19it/s]:  85%|█████████████████████████████████████████▋       | 34/40 [00:00<00:00, 162.04it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 161.89it/s]
# 23 May 15:51    INFO  epoch 5 training [time: 0.26s, train loss: 150.6758]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 230.88it/s]
# 23 May 15:51    INFO  epoch 5 evaluating [time: 0.03s, valid_score: 0.219200]
# 23 May 15:51    INFO  valid result:
# rmse : 0.2192    mae : 0.1826
# 23 May 15:51    INFO  Saving current: saved/AFM-May-23-2024_15-51-17.pth
# Train     6:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  40%|███████████████████▌                             | 16/40 [00:00<00:00, 158.99it/s]:  80%|███████████████████████████████████████▏         | 32/40 [00:00<00:00, 158.18it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00,
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 299.28it/s]
# 23 May 15:51    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |    34.80 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.54 G/13.86 G |
# +-------------+----------------+
# 23 May 15:51    INFO  best valid : OrderedDict([('rmse', 0.1833), ('mae', 0.144)])
# 23 May 15:51    INFO  test result: OrderedDict([('rmse', 0.1843), ('mae', 0.1449)])
# {'best_valid_score': 0.1833,
#  'valid_score_bigger': False,
#  'best_valid_result': OrderedDict([('rmse', 0.1833), ('mae', 0.144)]),
#  'test_result': OrderedDict([('rmse', 0.1843), ('mae', 0.1449)])}

# %%
import pandas as pd
from recbole.quick_start import run_recbole

# Load data and treat any rating as an interaction (implicit feedback)
data = pd.read_csv('u.data', sep='\t', names=['user_id', 'item_id', 'rating', 'timestamp'])
data['rating'] = (data['rating'] > 0).astype(int)  # Convert ratings to 1 to denote interaction

# Save the data with simple headers
data.to_csv('dataset/ml100k_implicit_afm/ml100k_implicit_afm.inter', index=False, sep='\t',
            header=['user_id:token', 'item_id:token', 'rating:float', 'timestamp:float'])

# Configuration for AFM with implicit feedback
config_dict_implicit = {
    'model': 'AFM',
    'dataset': 'ml100k_implicit_afm',
    'epochs': 100,
    'learning_rate': 0.01,
    'eval_setting': 'RO_RS',  # Random Ordering, Random Splitting
    'metrics': ['RMSE', 'MAE'],  # Evaluation metrics suitable for binary classification
    'valid_metric': 'RMSE',  # Main metric for validation
    'topk': 10,
    'early_stop': 5,
    'gpu_id': 0,
    'LABEL_FIELD': 'rating',  # This must match exactly with your data headers
    'load_col': {'inter': ['user_id', 'item_id', 'rating', 'timestamp']}
}

# Run the model
run_recbole(model='AFM', dataset='ml100k_implicit_afm', config_dict=config_dict_implicit)
# Out:
# 23 May 15:52    INFO  ['/home/stef/.local/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/home/stef/.local/share/jupyter/runtime/kernel-510548df-5f9c-4af3-8da9-9e6950dbae6c.json']
# 23 May 15:52    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/ml100k_implicit_afm
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.01
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': None, 'mode': {'valid': 'labeled', 'test': 'labeled'}}
# repeatable = False
# metrics = ['RMSE', 'MAE']
# topk = [10]
# valid_metric = RMSE
# valid_metric_bigger = False
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = rating
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'rating', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 10
# attention_size = 25
# dropout_prob = 0.3
# reg_weight = 2.0
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.CONTEXT
# eval_setting = RO_RS
# early_stop = 5
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.VALUE
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'none', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'none', 'sample_num': 'none'}
#
#
# /home/stef/.local/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# /home/stef/.local/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:650: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=feat[field].mean(), inplace=True)
# 23 May 15:52    INFO  ml100k_implicit_afm
# The number of users: 944
# Average actions of users: 106.04453870625663
# The number of items: 1683
# Average actions of items: 59.45303210463734
# The number of inters: 100000
# The sparsity of the dataset: 93.70575143257098%
# Remain Fields: ['user_id', 'item_id', 'rating', 'timestamp']
# 23 May 15:52    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}]
# 23 May 15:52    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': None, 'mode': {'valid': 'labeled', 'test': 'labeled'}}]
# 23 May 15:52    INFO  AFM(
#   (token_embedding_table): FMEmbedding(
#     (embedding): Embedding(2627, 10)
#   )
#   (first_order_linear): FMFirstOrderLinear(
#     (token_embedding_table): FMEmbedding(
#       (embedding): Embedding(2627, 1)
#     )
#   )
#   (attlayer): AttLayer(
#     (w): Linear(in_features=10, out_features=25, bias=False)
#   )
#   (dropout_layer): Dropout(p=0.3, inplace=False)
#   (sigmoid): Sigmoid()
#   (loss): BCEWithLogitsLoss()
# )
# Trainable parameters: 29183
# 23 May 15:52    INFO  FLOPs: 272.0
# Train     0:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  48%|███████████████████████▎                         | 19/40 [00:00<00:00, 186.76it/s]:  95%|██████████████████████████████████████████████▌  | 38/40 [00:00<00:00, 166.88it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 160.50it/s]
# 23 May 15:52    INFO  epoch 0 training [time: 0.26s, train loss: 172.9349]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 163.59it/s]
# 23 May 15:52    INFO  epoch 0 evaluating [time: 0.03s, valid_score: 0.183900]
# 23 May 15:52    INFO  valid result:
# rmse : 0.1839    mae : 0.1797
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train     1:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  52%|█████████████████████████▋                       | 21/40 [00:00<00:00, 203.23it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 182.17it/s]
# 23 May 15:52    INFO  epoch 1 training [time: 0.23s, train loss: 15.6941]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 263.32it/s]
# 23 May 15:52    INFO  epoch 1 evaluating [time: 0.03s, valid_score: 0.018700]
# 23 May 15:52    INFO  valid result:
# rmse : 0.0187    mae : 0.0087
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train     2:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  48%|███████████████████████▎                         | 19/40 [00:00<00:00, 184.69it/s]:  95%|██████████████████████████████████████████████▌  | 38/40 [00:00<00:00, 173.86it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 171.64it/s]
# 23 May 15:52    INFO  epoch 2 training [time: 0.24s, train loss: 1.4140]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 257.85it/s]
# 23 May 15:52    INFO  epoch 2 evaluating [time: 0.02s, valid_score: 0.011000]
# 23 May 15:52    INFO  valid result:
# rmse : 0.011    mae : 0.0025
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train     3:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  48%|███████████████████████▎                         | 19/40 [00:00<00:00, 187.26it/s]:  95%|██████████████████████████████████████████████▌  | 38/40 [00:00<00:00, 171.88it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 168.88it/s]
# 23 May 15:52    INFO  epoch 3 training [time: 0.25s, train loss: 0.8165]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 219.86it/s]
# 23 May 15:52    INFO  epoch 3 evaluating [time: 0.03s, valid_score: 0.009900]
# 23 May 15:52    INFO  valid result:
# rmse : 0.0099    mae : 0.0014
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train     4:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  42%|████████████████████▊                            | 17/40 [00:00<00:00, 162.43it/s]:  85%|█████████████████████████████████████████▋       | 34/40 [00:00<00:00, 164.35it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 165.63it/s]
# 23 May 15:52    INFO  epoch 4 training [time: 0.25s, train loss: 0.6689]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 289.64it/s]
# 23 May 15:52    INFO  epoch 4 evaluating [time: 0.02s, valid_score: 0.009600]
# 23 May 15:52    INFO  valid result:
# rmse : 0.0096    mae : 0.0009
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train     5:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  48%|███████████████████████▎                         | 19/40 [00:00<00:00, 185.92it/s]:  95%|██████████████████████████████████████████████▌  | 38/40 [00:00<00:00, 172.47it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 171.05it/s]
# 23 May 15:52    INFO  epoch 5 training [time: 0.25s, train loss: 0.5476]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 251.37it/s]
# 23 May 15:52    INFO  epoch 5 evaluating [time: 0.03s, valid_score: 0.009400]
# 23 May 15:52    INFO  valid result:
# rmse : 0.0094    mae : 0.0007
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train     6:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  48%|███████████████████████▎                         | 19/40 [00:00<00:00, 186.86it/s]:  98%|███████████████████████████████████████████████▊ | 39/40 [00:00<00:00, 193.13it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 187.35it/s]
# 23 May 15:52    INFO  epoch 6 training [time: 0.23s, train loss: 0.5206]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 234.55it/s]
# 23 May 15:52    INFO  epoch 6 evaluating [time: 0.03s, valid_score: 0.009300]
# 23 May 15:52    INFO  valid result:
# rmse : 0.
/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 180.18it/s]
# 23 May 15:52    INFO  epoch 16 training [time: 0.23s, train loss: 0.4858]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 202.60it/s]
# 23 May 15:52    INFO  epoch 16 evaluating [time: 0.03s, valid_score: 0.009100]
# 23 May 15:52    INFO  valid result:
# rmse : 0.0091    mae : 0.0004
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    17:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  50%|████████████████████████▌                        | 20/40 [00:00<00:00, 199.49it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 173.46it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 171.28it/s]
# 23 May 15:52    INFO  epoch 17 training [time: 0.25s, train loss: 0.5315]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 157.61it/s]
# 23 May 15:52    INFO  epoch 17 evaluating [time: 0.04s, valid_score: 0.009100]
# 23 May 15:52    INFO  valid result:
# rmse : 0.0091    mae : 0.0004
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    18:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  40%|███████████████████▌                             | 16/40 [00:00<00:00, 158.78it/s]:  88%|██████████████████████████████████████████▉      | 35/40 [00:00<00:00, 172.68it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 172.34it/s]
# 23 May 15:52    INFO  epoch 18 training [time: 0.25s, train loss: 0.5289]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 194.11it/s]
# 23 May 15:52    INFO  epoch 18 evaluating [time: 0.03s, valid_score: 0.009100]
# 23 May 15:52    INFO  valid result:
# rmse : 0.0091    mae : 0.0004
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    19:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  45%|██████████████████████                           | 18/40 [00:00<00:00, 172.15it/s]:  90%|████████████████████████████████████████████     | 36/40 [00:00<00:00, 163.36it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 161.09it/s]
# 23 May 15:52    INFO  epoch 19 training [time: 0.26s, train loss: 0.5592]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 201.04it/s]
# 23 May 15:52    INFO  epoch 19 evaluating [time: 0.03s, valid_score: 0.009000]
# 23 May 15:52    INFO  valid result:
# rmse : 0.009    mae : 0.0004
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    20:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  50%|████████████████████████▌                        | 20/40 [00:00<00:00, 195.72it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 185.00it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 182.38it/s]
# 23 May 15:52    INFO  epoch 20 training [time: 0.23s, train loss: 0.5530]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 240.96it/s]
# 23 May 15:52    INFO  epoch 20 evaluating [time: 0.03s, valid_score: 0.009000]
# 23 May 15:52    INFO  valid result:
# rmse : 0.009    mae : 0.0003
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    21:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  42%|████████████████████▊                            | 17/40 [00:00<00:00, 165.57it/s]:  92%|█████████████████████████████████████████████▎   | 37/40 [00:00<00:00, 182.10it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 176.23it/s]
# 23 May 15:52    INFO  epoch 21 training [time: 0.24s, train loss: 0.5664]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 270.37it/s]
# 23 May 15:52    INFO  epoch 21 evaluating [time: 0.02s, valid_score: 0.009000]
# 23 May 15:52    INFO  valid result:
# rmse : 0.009    mae : 0.0003
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    22:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  45%|██████████████████████                           | 18/40 [00:00<00:00, 174.98it/s]:  92%|█████████████████████████████████████████████▎   | 37/40 [00:00<00:00, 180.45it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 176.43it/s]
# 23 May 15:52    INFO  epoch 22 training [time: 0.24s, train loss: 0.5245]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 248.26it/s]
# 23 May 15:52    INFO  epoch 22 evaluating [time: 0.03s, valid_score: 0.009000]
# 23 May 15:52    INFO  valid result:
# rmse : 0.009    mae : 0.0003
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    23:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  45%|██████████████████████                           | 18/40 [00:00<00:00, 173.94it/s]:  90%|████████████████████████████████████████████     | 36/40 [00:00<00:00, 168.32it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 166.96it/s]
# 23 May 15:52    INFO  epoch 23 training [time: 0.25s, train loss: 0.5822]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 263.91it/s]
# 23 May 15:52    INFO  epoch 23 evaluating [time: 0.02s, valid_score: 0.009000]
# 23 May 15:52    INFO  valid result:
# rmse : 0.009    mae : 0.0003
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    24:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  48%|███████████████████████▎                         | 19/40 [00:00<00:00, 186.97it/s]:  95%|██████████████████████████████████████████████▌  | 38/40 [00:00<00:00, 175.53it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 170.10it/s]
# 23 May 15:52    INFO  epoch 24 training [time: 0.25s, train loss: 0.5301]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 226.38it/s]
# 23 May 15:52    INFO  epoch 24 evaluating [time: 0.03s, valid_score: 0.009000]
# 23 May 15:52    INFO  valid result:
# rmse : 0.009    mae : 0.0003
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    25:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  42%|████████████████████▊                            | 17/40 [00:00<00:00, 164.18it/s]:  85%|█████████████████████████████████████████▋       | 34/40 [00:00<00:00, 151.42it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00,
/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 133.79it/s]
# 23 May 15:52    INFO  epoch 94 training [time: 0.31s, train loss: 0.5968]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 177.45it/s]
# 23 May 15:52    INFO  epoch 94 evaluating [time: 0.04s, valid_score: 0.008600]
# 23 May 15:52    INFO  valid result:
# rmse : 0.0086    mae : 0.0003
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    95:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  38%|██████████████████▍                              | 15/40 [00:00<00:00, 142.45it/s]:  85%|█████████████████████████████████████████▋       | 34/40 [00:00<00:00, 166.26it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 156.52it/s]
# 23 May 15:52    INFO  epoch 95 training [time: 0.27s, train loss: 0.5859]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 146.55it/s]
# 23 May 15:52    INFO  epoch 95 evaluating [time: 0.04s, valid_score: 0.008600]
# 23 May 15:52    INFO  valid result:
# rmse : 0.0086    mae : 0.0003
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    96:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  30%|██████████████▋                                  | 12/40 [00:00<00:00, 113.43it/s]:  62%|██████████████████████████████▋                  | 25/40 [00:00<00:00, 119.33it/s]:  98%|███████████████████████████████████████████████▊ | 39/40 [00:00<00:00, 126.21it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 122.17it/s]
# 23 May 15:52    INFO  epoch 96 training [time: 0.35s, train loss: 0.5912]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 144.06it/s]
# 23 May 15:52    INFO  epoch 96 evaluating [time: 0.04s, valid_score: 0.008600]
# 23 May 15:52    INFO  valid result:
# rmse : 0.0086    mae : 0.0003
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    97:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  40%|███████████████████▌                             | 16/40 [00:00<00:00, 159.49it/s]:  80%|███████████████████████████████████████▏         | 32/40 [00:00<00:00, 153.87it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 155.36it/s]
# 23 May 15:52    INFO  epoch 97 training [time: 0.27s, train loss: 0.5753]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 174.04it/s]
# 23 May 15:52    INFO  epoch 97 evaluating [time: 0.03s, valid_score: 0.008600]
# 23 May 15:52    INFO  valid result:
# rmse : 0.0086    mae : 0.0003
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    98:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  38%|██████████████████▍                              | 15/40 [00:00<00:00, 142.39it/s]:  75%|████████████████████████████████████▊            | 30/40 [00:00<00:00, 142.10it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 142.87it/s]
# 23 May 15:52    INFO  epoch 98 training [time: 0.30s, train loss: 0.6082]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 188.74it/s]
# 23 May 15:52    INFO  epoch 98 evaluating [time: 0.03s, valid_score: 0.008600]
# 23 May 15:52    INFO  valid result:
# rmse : 0.0086    mae : 0.0003
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# Train    99:   0%|                                                           | 0/40 [00:00<?, ?it/s]:  35%|█████████████████▏                               | 14/40 [00:00<00:00, 135.81it/s]:  70%|██████████████████████████████████▎              | 28/40 [00:00<00:00, 134.27it/s]: 100%|█████████████████████████████████████████████████| 40/40 [00:00<00:00, 136.42it/s]
# 23 May 15:52    INFO  epoch 99 training [time: 0.30s, train loss: 0.5998]
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 128.62it/s]
# 23 May 15:52    INFO  epoch 99 evaluating [time: 0.04s, valid_score: 0.008600]
# 23 May 15:52    INFO  valid result:
# rmse : 0.0086    mae : 0.0003
# 23 May 15:52    INFO  Saving current: saved/AFM-May-23-2024_15-52-12.pth
# 23 May 15:52    INFO  Loading model structure and parameters from saved/AFM-May-23-2024_15-52-12.pth
# Evaluate   :   0%|                                                            | 0/3 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 3/3 [00:00<00:00, 188.84it/s]
# 23 May 15:52    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |    37.70 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.54 G/13.86 G |
# +-------------+----------------+
# 23 May 15:52    INFO  best valid : OrderedDict([('rmse', 0.0086), ('mae', 0.0003)])
# 23 May 15:52    INFO  test result: OrderedDict([('rmse', 0.0119), ('mae', 0.0006)])
# {'best_valid_score': 0.0086,
#  'valid_score_bigger': False,
#  'best_valid_result': OrderedDict([('rmse', 0.0086), ('mae', 0.0003)]),
#  'test_result': OrderedDict([('rmse', 0.0119), ('mae', 0.0006)])}

# %% [markdown]
# #Amazon Dataset Subsets (10 smallest)
#
# source:
# https://cseweb.ucsd.edu/~jmcauley/datasets/amazon/links.html
#
# The code provided efficiently processes multiple datasets, subsets from the "Amazon Review 2014" dataset to prepare them for use with RecBole, a recommender system framework. It reads each dataset, renames columns to match the required format (`user_id:token`, `item_id:token`, `rating:float`, `timestamp:float`), and then saves the data into three files: an interaction file (`*.inter`), a user file (`*.user`), and an item file (`*.item`). The code also ensures that each dataset's output files are stored in a structured directory, and it confirms the success of each step by printing the first few rows of the generated files.

# %%
import os
import pandas as pd

# List of datasets
files = [
    'ratings_Amazon_Instant_Video.csv',
    'ratings_Musical_Instruments.csv',
    'ratings_Digital_Music.csv',
    'ratings_Baby.csv',
    'ratings_Patio_Lawn_and_Garden.csv',
    'ratings_Office_Products.csv',
    'ratings_Grocery_and_Gourmet_Food.csv',
    'ratings_Pet_Supplies.csv',
    'ratings_Automotive.csv',
    'ratings_Apps_for_Android.csv'
]

# Function to process each file
def process_file(file_name):
    # Load the dataset
    df = pd.read_csv(file_name, header=None)

    # Rename columns to match RecBole's requirements
    df.columns = ['user_id:token', 'item_id:token', 'rating:float', 'timestamp:float']

    # Create the directory structure
    dataset_name = os.path.splitext(file_name)[0]  # Remove .csv extension
    output_dir = f'dataset/{dataset_name}'
    os.makedirs(output_dir, exist_ok=True)

    # Save the interaction file
    output_file_inter = f'{output_dir}/{dataset_name}.inter'
    df.to_csv(output_file_inter, index=False, sep='\t')

    # Create and save the user file
    user_df = pd.DataFrame(df['user_id:token'].unique(), columns=['user_id:token'])
    output_file_user = f'{output_dir}/{dataset_name}.user'
    user_df.to_csv(output_file_user, index=False, sep='\t')

    # Create and save the item file
    item_df = pd.DataFrame(df['item_id:token'].unique(), columns=['item_id:token'])
    output_file_item = f'{output_dir}/{dataset_name}.item'
    item_df.to_csv(output_file_item, index=False, sep='\t')

    # Print out the first few rows of each file for confirmation
    print(f"First few rows of the interaction file for {dataset_name}:")
    print(df.head())
    print(f"Interaction file saved as '{output_file_inter}'.")

    print(f"First few lines of the user file for {dataset_name}:")
    print(user_df.head())
    print(f"User file saved as '{output_file_user}'.")

    print(f"First few lines of the item file for {dataset_name}:")
    print(item_df.head())
    print(f"Item file saved as '{output_file_item}'.")
    print("-" * 30)

# Process each file in the list
for file in files:
    process_file(file)
# Out:
# First few rows of the interaction file for ratings_Amazon_Instant_Video:
#     user_id:token item_id:token  rating:float  timestamp:float
# 0  A1EE2E3N7PW666    B000GFDAUG           5.0       1202256000
# 1   AGZ8SM1BGK3CK    B000GFDAUG           5.0       1198195200
# 2  A2VHZ21245KBT7    B000GIOPK2           4.0       1215388800
# 3   ACX8YW2D5EGP6    B000GIOPK2           4.0       1185840000
# 4   A9RNMO9MUSMTJ    B000GIOPK2           2.0       1281052800
# Interaction file saved as 'dataset/ratings_Amazon_Instant_Video/ratings_Amazon_Instant_Video.inter'.
# First few lines of the user file for ratings_Amazon_Instant_Video:
#     user_id:token
# 0  A1EE2E3N7PW666
# 1   AGZ8SM1BGK3CK
# 2  A2VHZ21245KBT7
# 3   ACX8YW2D5EGP6
# 4   A9RNMO9MUSMTJ
# User file saved as 'dataset/ratings_Amazon_Instant_Video/ratings_Amazon_Instant_Video.user'.
# First few lines of the item file for ratings_Amazon_Instant_Video:
#   item_id:token
# 0    B000GFDAUG
# 1    B000GIOPK2
# 2    B000GIPKWY
# 3    B000GJUQ7M
# 4    B000GK0NBK
# Item file saved as 'dataset/ratings_Amazon_Instant_Video/ratings_Amazon_Instant_Video.item'.
# ------------------------------
# First few rows of the interaction file for ratings_Musical_Instruments:
#     user_id:token item_id:token  rating:float  timestamp:float
# 0  A1YS9MDZP93857    0006428320           3.0       1394496000
# 1  A3TS466QBAWB9D    0014072149           5.0       1370476800
# 2  A3BUDYITWUSIS7    0041291905           5.0       1381708800
# 3  A19K10Z0D2NTZK    0041913574           5.0       1285200000
# 4  A14X336IB4JD89    0201891859           1.0       1350432000
# Interaction file saved as 'dataset/ratings_Musical_Instruments/ratings_Musical_Instruments.inter'.
# First few lines of the user file for ratings_Musical_Instruments:
#     user_id:token
# 0  A1YS9MDZP93857
# 1  A3TS466QBAWB9D
# 2  A3BUDYITWUSIS7
# 3  A19K10Z0D2NTZK
# 4  A14X336IB4JD89
# User file saved as 'dataset/ratings_Musical_Instruments/ratings_Musical_Instruments.user'.
# First few lines of the item file for ratings_Musical_Instruments:
#   item_id:token
# 0    0006428320
# 1    0014072149
# 2    0041291905
# 3    0041913574
# 4    0201891859
# Item file saved as 'dataset/ratings_Musical_Instruments/ratings_Musical_Instruments.item'.
# ------------------------------
# First few rows of the interaction file for ratings_Digital_Music:
#     user_id:token item_id:token  rating:float  timestamp:float
# 0  A2EFCYXHNK06IS    5555991584           5.0        978480000
# 1  A1WR23ER5HMAA9    5555991584           5.0        953424000
# 2  A2IR4Q0GPAFJKW    5555991584           4.0       1393545600
# 3  A2V0KUVAB9HSYO    5555991584           4.0        966124800
# 4  A1J0GL9HCA7ELW    5555991584           5.0       1007683200
# Interaction file saved as 'dataset/ratings_Digital_Music/ratings_Digital_Music.inter'.
# First few lines of the user file for ratings_Digital_Music:
#     user_id:token
# 0  A2EFCYXHNK06IS
# 1  A1WR23ER5HMAA9
# 2  A2IR4Q0GPAFJKW
# 3  A2V0KUVAB9HSYO
# 4  A1J0GL9HCA7ELW
# User file saved as 'dataset/ratings_Digital_Music/ratings_Digital_Music.user'.
# First few lines of the item file for ratings_Digital_Music:
#   item_id:token
# 0    5555991584
# 1    6308051551
# 2    7901622466
# 3    B0000000ZW
# 4    B00000016T
# Item file saved as 'dataset/ratings_Digital_Music/ratings_Digital_Music.item'.
# ------------------------------
# First few rows of the interaction file for ratings_Baby:
#     user_id:token item_id:token  rating:float  timestamp:float
# 0  A28O3NP6WR5517    0188399313           5.0       1369612800
# 1   AX0M1Z6ZWO52J    0188399399           5.0       1365465600
# 2  A1KD7N84L7NIUT    0188399518           4.0       1392336000
# 3  A29CUDEIF4X1UO    0188399518           3.0       1373241600
# 4  A32592TYN6C9EM    0316967297           4.0       1378425600
# Interaction file saved as 'dataset/ratings_Baby/ratings_Baby.inter'.
# First few lines of the user file for ratings_Baby:
#     user_id:token
# 0  A28O3NP6WR5517
# 1   AX0M1Z6ZWO52J
# 2  A1KD7N84L7NIUT
# 3  A29CUDEIF4X1UO
# 4  A32592TYN6C9EM
# User file saved as 'dataset/ratings_Baby/ratings_Baby.user'.
# First few lines of the item file for ratings_Baby:
#   item_id:token
# 0    0188399313
# 1    0188399399
# 2    0188399518
# 3    0316967297
# 4    0615447279
# Item file saved as 'dataset/ratings_Baby/ratings_Baby.item'.
# ------------------------------
# First few rows of the interaction file for ratings_Patio_Lawn_and_Garden:
#     user_id:token item_id:token  rating:float  timestamp:float
# 0  A2VNYWOPJ13AFP    0981850006           5.0       1259798400
# 1  A20DWVV8HML3AW    0981850006           5.0       1371081600
# 2  A3RVP3YBYYOPRH    0981850006           5.0       1257984000
# 3  A28XY55TP3Q90O    0981850006           5.0       1314144000
# 4  A3VZW1BGUQO0V3    0981850006           5.0       1308268800
# Interaction file saved as 'dataset/ratings_Patio_Lawn_and_Garden/ratings_Patio_Lawn_and_Garden.inter'.
# First few lines of the user file for ratings_Patio_Lawn_and_Garden:
#     user_id:token
# 0  A2VNYWOPJ13AFP
# 1  A20DWVV8HML3AW
# 2  A3RVP3YBYYOPRH
# 3  A28XY55TP3Q90O
# 4  A3VZW1BGUQO0V3
# User file saved as 'dataset/ratings_Patio_Lawn_and_Garden/ratings_Patio_Lawn_and_Garden.user'.
# First few lines of the item file for ratings_Patio_Lawn_and_Garden:
#   item_id:token
# 0    0981850006
# 1    144072007X
# 2    1554701503
# 3    1579822932
# 4    1754164498
# Item file saved as 'dataset/ratings_Patio_Lawn_and_Garden/ratings_Patio_Lawn_and_Garden.item'.
# ------------------------------
# First few rows of the interaction file for ratings_Office_Products:
#     user_id:token item_id:token  rating:float  timestamp:float
# 0  A2UESEUCI73CBO    0078800242           5.0       1374192000
# 1  A3BBNK2R5TUYGV    0113000316           5.0       1359417600
# 2   A5J78T14FJ5DU    0113000316           3.0       1318723200
# 3  A2P462UH5L6T57    043928631X           5.0       1356912000
# 4  A2E0X1MWNRTQF4    0439340039           1.0       1379721600
# Interaction file saved as 'dataset/ratings_Office_Products/ratings_Office_Products.inter'.
# First few lines of the user file for ratings_Office_Products:
#     user_id:token
# 0  A2UESEUCI73CBO
# 1  A3BBNK2R5TUYGV
# 2   A5J78T14FJ5DU
# 3  A2P462UH5L6T57
# 4  A2E0X1MWNRTQF4
# User file saved as 'dataset/ratings_Office_Products/ratings_Office_Products.user'.
# First few lines of the item file for ratings_Office_Products:
#   item_id:token
# 0    0078800242
# 1    0113000316
# 2    043928631X
# 3    0439340039
# 4    0439394058
# Item file saved as 'dataset/ratings_Office_Products/ratings_Office_Products.item'.
# ------------------------------
# First few rows of the interaction file for ratings_Grocery_and_Gourmet_Food:
#     user_id:token item_id:token  rating:float  timestamp:float
# 0  A1ZQZ8RJS1XVTX    0657745316           5.0       1381449600
# 1  A31W38VGZAUUM4    0700026444           5.0       1354752000
# 2  A3I0AV0UJX5OH0    1403796890           1.0       1385942400
# 3  A3QAAOLIXKV383    1403796890           3.0       1307836800
# 4   AB1A5EGHHVA9M    141278509X           5.0       1332547200
# Interaction file saved as 'dataset/ratings_Grocery_and_Gourmet_Food/ratings_Grocery_and_Gourmet_Food.inter'.
# First few lines of the user file for ratings_Grocery_and_Gourmet_Food:
#     user_id:token
# 0  A1ZQZ8RJS1XVTX
# 1  A31W38VGZAUUM4
# 2  A3I0AV0UJX5OH0
# 3  A3QAAOLIXKV383
# 4   AB1A5EGHHVA9M
# User file saved as 'dataset/ratings_Grocery_and_Gourmet_Food/ratings_Grocery_and_Gourmet_Food.user'.
# First few lines of the item file for ratings_Grocery_and_Gourmet_Food:
#   item_id:token
# 0    0657745316
# 1    0700026444
# 2    1403796890
# 3    141278509X
# 4    1453060375
# Item file saved as 'dataset/ratings_Grocery_and_Gourmet_Food/ratings_Grocery_and_Gourmet_Food.item'.
# ------------------------------
# First few rows of the interaction file for ratings_Pet_Supplies:
#     user_id:token item_id:token  rating:float  timestamp:float
# 0  A3PG0KS1YE8MR4    0615553605           5.0       1354838400
# 1  A363P047LR5XI6    0615553605           4.0       1373932800
# 2    ABZ8CQXD42H4    0615553605           1.0       1386028800
# 3  A3J8QW1MV1OP01    0615583474           5.0       1347321600
# 4  A3ISA8Z0NB0ILH    0615583474           5.0       1358899200
# Interaction file saved as 'dataset/ratings_Pet_Supplies/ratings_Pet_Supplies.inter'.
# First few lines of the user file for ratings_Pet_Supplies:
#     user_id:token
# 0  A3PG0KS1YE8MR4
# 1  A363P047LR5XI6
# 2    ABZ8CQXD42H4
# 3  A3J8QW1MV1OP01
# 4  A3ISA8Z0NB0ILH
# User file saved as 'dataset/ratings_Pet_Supplies/ratings_Pet_Supplies.user'.
# First few lines of the item file for ratings_Pet_Supplies:
#   item_id:token
# 0    0615553605
# 1    0615583474
# 2    0972585419
# 3    0975412809
# 4    0975412868
# Item file saved as 'dataset/ratings_Pet_Supplies/ratings_Pet_Supplies.item'.
# ------------------------------
# First few rows of the interaction file for ratings_Automotive:
#     user_id:token item_id:token  rating:float  timestamp:float
# 0  A108J5O7DG2WIM    0219400083           4.0       1376697600
# 1  A1QBLUSZW281TA    0715000322           5.0       1396915200
# 2  A3B40ZIZJ3HEP7    0970408641           1.0       1332115200
# 3  A1DUAXYX5WHSX1    1940825172           4.0       1404691200
# 4  A1VS7YWE0NCAS3    2409862403           4.0       1381363200
# Interaction file saved as 'dataset/ratings_Automotive/ratings_Automotive.inter'.
# First few lines of the user file for ratings_Automotive:
#     user_id:token
# 0  A108J5O7DG2WIM
# 1  A1QBLUSZW281TA
# 2  A3B40ZIZJ3HEP7
# 3  A1DUAXYX5WHSX1
# 4  A1VS7YWE0NCAS3
# User file saved as 'dataset/ratings_Automotive/ratings_Automotive.user'.
# First few lines of the item file for ratings_Automotive:
#   item_id:token
# 0    0219400083
# 1    0715000322
# 2    0970408641
# 3    1940825172
# 4    2409862403
# Item file saved as 'dataset/ratings_Automotive/ratings_Automotive.item'.
# ------------------------------
# First few rows of the interaction file for ratings_Apps_for_Android:
#     user_id:token item_id:token  rating:float  timestamp:float
# 0   AUI0OLXAB3KKT    B004A9SDD8           5.0       1301184000
# 1  A1ZUSQ3TC3EC4C    B004A9SDD8           5.0       1321574400
# 2   AC05OAXD72X1V    B004A9SDD8           4.0       1367366400
# 3  A2RVMFOKBVM21I    B004A9SDD8           5.0       1350172800
# 4  A3NBSRGUWQGCMZ    B004A9SDD8           1.0       1300838400
# Interaction file saved as 'dataset/ratings_Apps_for_Android/ratings_Apps_for_Android.inter'.
# First few lines of the user file for ratings_Apps_for_Android:
#     user_id:token
# 0   AUI0OLXAB3KKT
# 1  A1ZUSQ3TC3EC4C
# 2   AC05OAXD72X1V
# 3  A2RVMFOKBVM21I
# 4  A3NBSRGUWQGCMZ
# User file saved as 'dataset/ratings_Apps_for_Android/ratings_Apps_for_Android.user'.
# First few lines of the item file for ratings_Apps_for_Android:
#   item_id:token
# 0    B004A9SDD8
# 1    B004AFQAUA
# 2    B004AGCR1K
# 3    B004AHBBPW
# 4    B004ALFHV2
# Item file saved as 'dataset/ratings_Apps_for_Android/ratings_Apps_for_Android.item'.
# ------------------------------

# %% [markdown]
# # Google Restaurants 108K dataset
#
# source:
# https://cseweb.ucsd.edu/~jmcauley/datasets.html#google_restaurants
# https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal_restaurants/
#
# ## Original Dataset Information
#
# - **Dataset Name**: google_restaurants_108K.json
# - **File Size**: 112 MB
# - **Features** (in the 'train' part of the data):
#   - `user_id`
#   - `business_id`
#   - `rating`
#
# ## Edited Dataset Information
#
# ### Interaction File (`*.inter`)
#
# - **Features**:
#   - `user_id:token` (corresponds to `user_id`)
#   - `item_id:token` (corresponds to `business_id`)
#   - `rating:float` (corresponds to `rating`)
#
# ### User File (`*.user`)
#
# - **Features**:
#   - `user_id:token` (list of unique user IDs from `user_id`)
#
# ### Item File (`*.item`)
#
# - **Features**:
#   - `item_id:token` (list of unique item IDs from `business_id`)

# %%
import os
import pandas as pd
import json

# Load the dataset
file_path = 'google_restaurants_108K.json'
with open(file_path, 'r') as f:
    data = json.load(f)

# Flatten the 'train' part of the data
df_train = pd.json_normalize(data['train'])

# Extract only the necessary columns for RecBole
df_inter = df_train[['user_id', 'business_id', 'rating']]

# Rename columns to match RecBole's expected format
df_inter.columns = ['user_id:token', 'item_id:token', 'rating:float']

# Create the directory structure
output_dir = 'dataset/google_restaurants_108K'
os.makedirs(output_dir, exist_ok=True)

# Save the interaction file without a timestamp
output_file_inter = f'{output_dir}/google_restaurants_108K.inter'
df_inter.to_csv(output_file_inter, index=False, sep='\t')

# Create and save the user file
user_df = pd.DataFrame(df_inter['user_id:token'].unique(), columns=['user_id:token'])
output_file_user = f'{output_dir}/google_restaurants_108K.user'
user_df.to_csv(output_file_user, index=False, sep='\t')

# Create and save the item file
item_df = pd.DataFrame(df_inter['item_id:token'].unique(), columns=['item_id:token'])
output_file_item = f'{output_dir}/google_restaurants_108K.item'
item_df.to_csv(output_file_item, index=False, sep='\t')

# Print out the first few rows of each file for verification
print("First few rows of the interaction file:")
print(pd.read_csv(output_file_inter, sep='\t').head())

print("First few rows of the user file:")
print(pd.read_csv(output_file_user, sep='\t').head())

print("First few rows of the item file:")
print(pd.read_csv(output_file_item, sep='\t').head())

print("Data restructuring and verification complete. Files are ready for RecBole.")
# Out:
# First few rows of the interaction file:
#            user_id:token             item_id:token  rating:float
# 0  101074926318992653684  60567465d335d0abfb415b26             4
# 1  117065749986299237881  6050fa9f5b4ccec8d5cae994             5
# 2  106700937793048450809  604be10877e81aaed3cc9a1e             4
# 3  101643045857250355161  60411e017cd8bf130362365a             5
# 4  109802745326785766951  604139dd7cd8bf1303624208             4
# First few rows of the user file:
#            user_id:token
# 0  101074926318992653684
# 1  117065749986299237881
# 2  106700937793048450809
# 3  101643045857250355161
# 4  109802745326785766951
# First few rows of the item file:
#               item_id:token
# 0  60567465d335d0abfb415b26
# 1  6050fa9f5b4ccec8d5cae994
# 2  604be10877e81aaed3cc9a1e
# 3  60411e017cd8bf130362365a
# 4  604139dd7cd8bf1303624208
# Data restructuring and verification complete. Files are ready for RecBole.

# %% [markdown]
# # Kaggle Beer rating dataset
# source:
# https://www.kaggle.com/datasets/ankurnapa/rate-beer-data?resource=download
#
# ## Original Dataset Information
#
# - **Dataset Name**: beer_reviews.csv
# - **File Size**: 173 MB
# - **Features**:
#   - `brewery_id`
#   - `brewery_name`
#   - `review_time`
#   - `review_overall`
#   - `review_aroma`
#   - `review_appearance`
#   - `review_profilename`
#   - `beer_style`
#   - `review_palate`
#   - `review_taste`
#   - `beer_name`
#   - `beer_abv`
#   - `beer_beerid`
#
# ## Edited Dataset Information
#
# ### Interaction File (`*.inter`)
#
# - **Features**:
#   - `user_id:token` (corresponds to `review_profilename`)
#   - `item_id:token` (corresponds to `beer_beerid`)
#   - `rating:float` (corresponds to `review_overall`)
#
# ### User File (`*.user`)
#
# - **Features**:
#   - `user_id:token` (list of unique user IDs from `review_profilename`)
#
# ### Item File (`*.item`)
#
# - **Features**:
#   - `item_id:token` (list of unique item IDs from `beer_beerid`)
#
#
# ## Edited Dataset Information
#
# ### Interaction File (`*.inter`)
#
# - **Features**:
#   - `user_id:token` (corresponds to `review_profilename`)
#   - `item_id:token` (corresponds to `beer_beerid`)
#   - `rating:float` (corresponds to `review_overall`)
#
# ### User File (`*.user`)
#
# - **Features**:
#   - `user_id:token` (list of unique user IDs from `review_profilename`)
#
# ### Item File (`*.item`)
#
# - **Features**:
#   - `item_id:token` (list of unique item IDs from `beer_beerid`)

# %%
import pandas as pd

# Load the CSV file
file_path = 'beer_reviews.csv'
df = pd.read_csv(file_path)

# Display the first few rows to inspect the data
print("First few rows of the data:")
print(df.head())

# Display column names to understand the structure
print("\nColumn names:")
print(df.columns)

# Rename columns to match RecBole's requirements
df_inter = df.rename(columns={
    'review_profilename': 'user_id:token',
    'beer_beerid': 'item_id:token',
    'review_overall': 'rating:float'
})

# Display the first few rows of the interaction data
print("\nFirst few rows of the interaction file:")
print(df_inter[['user_id:token', 'item_id:token', 'rating:float']].head())

# Save the interaction data to *.inter file
inter_file_path = 'dataset/beer_reviews.inter'
df_inter[['user_id:token', 'item_id:token', 'rating:float']].to_csv(inter_file_path, index=False, header=False)

# Create and save the unique users and items
unique_users = df_inter['user_id:token'].drop_duplicates().reset_index(drop=True)
unique_items = df_inter['item_id:token'].drop_duplicates().reset_index(drop=True)

# Save the unique users to *.user file
user_file_path = 'dataset/beer_reviews.user'
unique_users.to_csv(user_file_path, index=False, header=False)

# Save the unique items to *.item file
item_file_path = 'dataset/beer_reviews.item'
unique_items.to_csv(item_file_path, index=False, header=False)

# Display the first few rows of the user and item files
print("\nFirst few rows of the user file:")
print(pd.read_csv(user_file_path, header=None).head())

print("\nFirst few rows of the item file:")
print(pd.read_csv(item_file_path, header=None).head())

print("\nFiles have been saved:")
print(f"Interaction file: {inter_file_path}")
print(f"User file: {user_file_path}")
print(f"Item file: {item_file_path}")
# Out:
# First few rows of the data:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# 2          Foreign / Export Stout            3.0           3.0
# 3                 German Pilsener            2.5           3.0
# 4  American Double / Imperial IPA            4.0           4.5
#
#                 beer_name  beer_abv  beer_beerid
# 0            Sausa Weizen       5.0        47986
# 1                Red Moon       6.2        48213
# 2  Black Horse Black Beer       6.5        48215
# 3              Sausa Pils       5.0        47969
# 4           Cauldron DIPA       7.7        64883
#
# Column names:
# Index(['brewery_id', 'brewery_name', 'review_time', 'review_overall',
#        'review_aroma', 'review_appearance', 'review_profilename', 'beer_style',
#        'review_palate', 'review_taste', 'beer_name', 'beer_abv',
#        'beer_beerid'],
#       dtype='object')
#
# First few rows of the interaction file:
#     user_id:token  item_id:token  rating:float
# 0         stcules          47986           1.5
# 1         stcules          48213           3.0
# 2         stcules          48215           3.0
# 3         stcules          47969           3.0
# 4  johnmichaelsen          64883           4.0
#
# First few rows of the user file:
#                 0
# 0         stcules
# 1  johnmichaelsen
# 2         oline73
# 3       Reidrover
# 4    alpinebryant
#
# First few rows of the item file:
#        0
# 0  47986
# 1  48213
# 2  48215
# 3  47969
# 4  64883
#
# Files have been saved:
# Interaction file: dataset/beer_reviews.inter
# User file: dataset/beer_reviews.user
# Item file: dataset/beer_reviews.item
